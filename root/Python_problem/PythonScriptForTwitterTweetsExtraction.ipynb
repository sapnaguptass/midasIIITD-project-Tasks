# %%
import tweepy
from textblob import TextBlob
#Variables that contains the user credentials to access Twitter API 
access_token = "*************************"
access_token_secret = "**********************"
consumer_key = "***********************"
consumer_secret = "**********************"
auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)
api=tweepy.API(auth)
public_tweets=api.search('@midasIIITD')
for tweet in public_tweets:
    print(tweet.text)
    print("Date and Time for Tweet",tweet.created_at)
    print("No of Favorites/Likes",tweet.favorite_count)
    print("No of retweets = ",tweet.retweet_count)
# Out:
# RT @midasIIITD: Many Congratulations to @midasIIITD student, Shagun Uppal @shagunuppls, on getting selected for the summer internship in th…
# Date and Time for Tweet 2019-04-08 12:32:22
# No of Favorites/Likes 0
# No of retweets =  2
# RT @midasIIITD: Many Congratulations to @midasIIITD student, Shagun Uppal @shagunuppls, on getting selected for the summer internship in th…
# Date and Time for Tweet 2019-04-08 07:09:00
# No of Favorites/Likes 0
# No of retweets =  2
# Many Congratulations to @midasIIITD student, Shagun Uppal @shagunuppls, on getting selected for the summer internsh… https://t.co/bzhiSm4zuB
# Date and Time for Tweet 2019-04-08 07:08:12
# No of Favorites/Likes 18
# No of retweets =  2
# @midasIIITD thanks all students who have appeared for the interview yesterday. We will announce the interview resul… https://t.co/qxESgZPtKJ
# Date and Time for Tweet 2019-04-08 03:27:42
# No of Favorites/Likes 5
# No of retweets =  0
# ...

# %%
timeline = api.user_timeline(count=300, screen_name = "@midasIIITD") 
for tweet in timeline:
    for media in tweet.entities.get("media",[{}]):
               
        if media.get("type",None) == "photo":
            # checks if the entity is of the type "photo"
            image_content=requests.get(media["media_url"])
            print ("Image Present")
            image_count = 1
        else:
            print("None")
            image_count = None
        print("No. of Images ",image_count)
# Out:
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# Image Present
# No. of Images  1
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# No. of Images  None
# None
# ...

# %% [markdown]
# # Text, Date&Time, No. of favorites/likes, No. of retweets and No. of Images of tweets

# %%
import requests
auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)
timeline = api.user_timeline(count=300, screen_name = "@midasIIITD") 
total_count=0
image_count= 0
for tweet in timeline:
    for media in tweet.entities.get("media",[{}]):
        #print (media)
        #checks if there is any media-entity
        print("Text of Tweet ",tweet.text)
        print("Date and Time for Tweet",tweet.created_at)
        print("No. of Favorites/Likes",tweet.favorite_count)
        print("No. of retweets = ",tweet.retweet_count)
        
        if media.get("type",None) == "photo":
            # checks if the entity is of the type "photo"
            image_content=requests.get(media["media_url"])
            print ("Image Present")
            image_count = 1
        else:
            print("None")
            image_count = None
        print("No. of Images ",image_count)
        total_count+=1
# Out:
# Text of Tweet  RT @IIITDelhi: Applications open for MTech (CB) through JNU CEEB Admission process. Candidates can check the JNU CEEB admission process in…
# Date and Time for Tweet 2019-04-10 04:51:26
# No. of Favorites/Likes 0
# No. of retweets =  1
# None
# No. of Images  None
# Text of Tweet  RT @IIITDelhi: We are delighted to share that IIIT-Delhi is ranked 55 by NIRF this year. We have moved up by 11 positions compared to the p…
# Date and Time for Tweet 2019-04-09 16:45:07
# No. of Favorites/Likes 0
# No. of retweets =  13
# None
# No. of Images  None
# Text of Tweet  RT @Harvard: Professor Jelani Nelson founded AddisCoder, a program that teaches students in Ethiopia how to code https://t.co/0sM06p4qxw
# Date and Time for Tweet 2019-04-09 05:04:27
# No. of Favorites/Likes 0
# No. of retweets =  35
# None
# No. of Images  None
# Text of Tweet  RT @emnlp2019: For anyone interested in submitting to EMNLP 2019, the anonymity period begins in less two weeks, on April 21.
# ...

# %%
print(count)
# Out:
# 200
